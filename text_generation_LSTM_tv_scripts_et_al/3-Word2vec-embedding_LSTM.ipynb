# %% [markdown]
# # Skip-gram Word2Vec With Negative Sampling
#
# In this notebook, PyTorch is used to implement the [Word2Vec algorithm](https://en.wikipedia.org/wiki/Word2vec) using the skip-gram architecture. By implementing this, we learn about embedding words for use in natural language processing.
#
# - First we define a 'basic' Word2Vec' NN that works fine but is very inefficient
# - Then we tune our algorithm by introducing 'Negative Sampling' to make training much faster. This also shows us
#     - How to use custom loss functions
#     - How to work with multiple forward functions
#
#
# **Readings** - The resources used to build this notebook:
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of Word2Vec from Chris McCormick
# * [First Word2Vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [Neural Information Processing Systems, paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for Word2Vec also from Mikolov et al.
#
# **Word embeddings**
#
# When dealing with words in text, you end up with tens of thousands of word classes to analyze; one for each word in a vocabulary. Trying to one-hot encode these words is massively inefficient because most values in a one-hot vector will be set to zero. So, the matrix multiplication that happens in between a one-hot input vector and a first, hidden layer will result in mostly zero-valued hidden outputs.
#
# <img src='assets/one_hot_encoding.png' width=50%>
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called **embeddings**. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# <img src='assets/lookup_matrix.png' width=50%>
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=50%>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. _The lookup is just a shortcut for the matrix multiplication._ The lookup table is trained just like any weight matrix.
#
# Embeddings aren't only used for words of course. We can use them for any model where we have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.
#
# **Word2Vec**
#
# The Word2Vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words.
#
# <img src="assets/context_drink.png" width=40%>
#
# Words that show up in similar **contexts**, such as "coffee", "tea", and "water" will have vectors near each other. Different words will be further away from one another, and relationships can be represented by distance in vector space.
#
# <img src="assets/vector_distance.png" width=40%>
#
#
# There are two architectures for implementing Word2Vec:
# >* CBOW (Continuous Bag-Of-Words) and
# * Skip-gram
#
# <img src="assets/word2vec_architectures.png" width=60%>
#
# In this implementation, we'll be using the **skip-gram architecture** because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.

# %% [markdown]
# ## Load the data
#
#
# 1. Load the [text8 dataset](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/October/5bbe6499_text8/text8.zip); a file of cleaned up *Wikipedia article text* from Matt Mahoney.
# 2. Extract that data in the `data` folder in the home directory.

# %%
# read in the extracted text file      
with open('data/text8') as f:
    text = f.read()

# print out the first 100 characters
print(text[:100])
# Out:
#  anarchism originated as a term of abuse first used against early working class radicals including t

# %% [markdown]
# ## Pre-processing
#
# Fix up the text to make training easier. This comes from the `utils.py` file. The `preprocess` function does a few things:
# >* It converts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems.
# * It removes all words that show up five or *fewer* times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations.
# * It returns a list of words in the text.

# %%
import utils

# get list of words
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
# print some stats about this word data
print("Total words in text: {}".format(len(words)))
print("Unique words: {}".format(len(set(words)))) # `set` removes any duplicate words
# Out:
# Total words in text: 16680599
# Unique words: 63641

# %% [markdown]
# ### Create Dictionaries
#
# Next, I'm creating two dictionaries to convert words to integers and back again (integers to words). This is again done with a function in the `utils.py` file. `create_lookup_tables` takes in a list of words in a text and returns two dictionaries.
# >* The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1, and so on.
#
# Once we have our dictionaries, the words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

print(int_words[:30])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580]

# %% [markdown]
# ### Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# $$ P(0) = 1 - \sqrt{\frac{1*10^{-5}}{1*10^6/16*10^6}} = 0.98735 $$

# %%
from collections import Counter
from random import choices, random
import random
import numpy as np
from tqdm import tqdm

threshold = 1e-5
word_counts = Counter(int_words)  # dictionary of int_words, how many times they appear
print(list(word_counts.items())[0])
# Out:
# (5233, 303)

# %%
"""First attempt - super slow"""

--break--
# Discard some frequent words, according to the subsampling equation
# Append rest to new list of words for training
train_words = []
options = [True, False]
for word, count in tqdm(word_counts.items()):
    p_word = 1 - np.sqrt(threshold / (count / len(set(int_words))))
    probs = [p_word, (1 - p_word)]
    decision = choices(options, probs)
    if decision[0]:
        train_words.append(word)


print(train_words[:30])
print(len(train_words))

# %%
"""Very quick alternative"""

total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

# Discard some frequent words, according to the subsampling equation
# Create a new list of words for training
train_words = [word for word in int_words if random() < (1 - p_drop[word])]

print(train_words[:30])
print(len(train_words))
# Out:
# [155, 741, 10571, 27349, 15067, 58112, 854, 3580, 10712, 104, 36, 2757, 686, 7088, 5233, 44611, 792, 5233, 1134, 8983, 4147, 4186, 32, 5233, 4860, 6753, 7573, 1774, 566, 11064]
# 4627507

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to define a surrounding _context_ and grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $[ 1: C ]$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Next step:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.
#
# Say, we have an input and we're interested in the idx=2 token, `741`:
# ```
# [5233, 58, 741, 10571, 27349, 0, 15067, 58112, 3580, 58, 10712]
# ```
#
# For `R=2`, `get_target` should return a list of four values:
# ```
# [5233, 58, 10571, 27349]
# ```

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    min_val = np.max([idx-R, 0])  # make sure no neg index occurs, not necessary for values at end
    target = words[min_val : idx] + words[idx+1 : idx+R+1]
    
    return target

# %% [markdown]
# ### Generating Batches
#
# Here's a generator function that returns batches of input and target data for our model, using the `get_target` function from above. The idea is that it grabs `batch_size` words from a words list. Then for each of those batches, it gets the target words in a window.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx : idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)  # each batch x and y will be one row of values
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
# Check function, visualize what happens 
int_text = [i for i in range(20)]
x, y = next(get_batches(int_text, batch_size=4, window_size=5))

print('x\n', x)
print('y\n', y)
# Out:
# x
#  [0, 1, 1, 2, 2, 2, 3]
# y
#  [1, 0, 2, 0, 1, 3, 2]

# %% [markdown]
# ## Building the graph
#
# Below is an approximate diagram of the general structure of our network.
# <img src="assets/skip_gram_net_arch.png" width=60%>
#
# >* The input words are passed in as batches of input word tokens.
# * This will go into a hidden layer of linear units (our embedding layer).
# * Then, finally into a softmax output layer.
#
# We'll use the softmax layer to make a prediction about the context words by sampling, as usual.
#
# The idea here is to train the embedding layer weight matrix to find efficient representations for our words. We can discard the softmax layer because we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in _other_ networks we build using this dataset.

# %% [markdown]
# ## Validation
#
# Here, we are creating a function that will help us observe our model as it learns. We're going to choose a few common words and a few uncommon words. Then, we'll print out the closest words to them using the cosine similarity:
#
# $$
# \mathrm{similarity} = \cos(\theta) = \frac{\vec{a} \cdot \vec{b}}{|\vec{a}||\vec{b}|}
# $$
#
#
# We can encode the validation words as vectors $\vec{a}$ using the embedding table, then calculate the similarity with each word vector $\vec{b}$ in the embedding table. With the similarities, we can print out the validation words and words in our embedding table semantically similar to those words. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
def cosine_similarity(embedding, valid_size=16, valid_window=100, device='cpu'):
    """ Returns the cosine similarity of validation words with words in the embedding matrix.
        Here, embedding should be a PyTorch embedding module.
    """
    
    # Calculate the cosine similarity between some random words and the embedding vectors. 
    # With the similarities, we can look at what words are close to our random words.
    # sim = (a . b) / |a||b|
    
    embed_vectors = embedding.weight
    
    # Calculate magnitude of embedding vectors, |b|
    magnitudes = embed_vectors.pow(2).sum(dim=1).sqrt().unsqueeze(0)
    
    # Pick N words from our ranges (0, window) and (1000, 1000+window). 
    # lower id implies more frequent words, higher id more uncommon words
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,
                               random.sample(range(1000, 1000+valid_window), valid_size//2))
    valid_examples = torch.LongTensor(valid_examples).to(device)
    
    valid_vectors = embedding(valid_examples)
    similarities = torch.mm(valid_vectors, embed_vectors.t())/magnitudes
        
    return valid_examples, similarities

# %% [markdown]
# ## (Basic) SkipGram model
#
# Define and train the SkipGram model.
# > You'll need to define an [embedding layer](https://pytorch.org/docs/stable/nn.html#embedding) and a final, softmax output layer.
#
# An Embedding layer takes in a number of inputs, importantly:
# * **num_embeddings** – the size of the dictionary of embeddings, or how many rows you'll want in the embedding weight matrix
# * **embedding_dim** – the size of each embedding vector; the embedding dimension

# %%
import torch
from torch import nn
import torch.optim as optim

# %%
class SkipGram(nn.Module):
    def __init__(self, n_vocab, n_embed):
        super().__init__()
        
        # complete this SkipGram model
        self.embed = nn.Embedding(n_vocab, n_embed)
        self.output = nn.Linear(n_embed, n_vocab)
        self.log_softmax = nn.log_softmax(dim=1)
        
    def forward(self, x):
        x = self.embed(x)
        scores = self.output(x)
        log_ps = self.log_softmax(scores)
        
        return x

# %% [markdown]
# **Problem with this architecture:** It actually works well, but takes hours to train even for only a small number of epochs ...  enter Negative Sampling

# %% [markdown]
# ---
# ## Negative Sampling
#
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct example, but only a small number of incorrect, or noise, examples. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf).
#
# There are two modifications we need to make. First, since we're not taking the softmax output over all the words, we're really only concerned with one output word at a time. Similar to how we use an embedding table to map the input word to the hidden layer, we can now use another embedding table to map the hidden layer to the output word. Now we have two embedding layers, one for input words and one for output words. Secondly, we use a modified loss function where we only care about the true example and a small subset of noise examples.
#
# $$
# - \large \log{\sigma\left(u_{w_O}\hspace{0.001em}^\top v_{w_I}\right)} -
# \sum_i^N \mathbb{E}_{w_i \sim P_n(w)}\log{\sigma\left(-u_{w_i}\hspace{0.001em}^\top v_{w_I}\right)}
# $$
#
# This is a little complicated so we'll go through it bit by bit. $u_{w_O}\hspace{0.001em}^\top$ is the embedding vector for our "output" target word (transposed, that's the $^\top$ symbol) and $v_{w_I}$ is the embedding vector for the "input" word. Then the first term
#
# $$\large \log{\sigma\left(u_{w_O}\hspace{0.001em}^\top v_{w_I}\right)}$$
#
# says we take the log-sigmoid of the inner product of the output word vector and the input word vector. Now the second term, let's first look at
#
# $$\large \sum_i^N \mathbb{E}_{w_i \sim P_n(w)}$$
#
# This means we're going to take a sum over words $w_i$ drawn from a noise distribution $w_i \sim P_n(w)$. The noise distribution is basically our vocabulary of words that aren't in the context of our input word. In effect, we can randomly sample words from our vocabulary to get these words. $P_n(w)$ is an arbitrary probability distribution though, which means we get to decide how to weight the words that we're sampling. This could be a uniform distribution, where we sample all words with equal probability. Or it could be according to the frequency that each word shows up in our text corpus, the unigram distribution $U(w)$. The authors found the best distribution to be $U(w)^{3/4}$, empirically.
#
# Finally, in
#
# $$\large \log{\sigma\left(-u_{w_i}\hspace{0.001em}^\top v_{w_I}\right)},$$
#
# we take the log-sigmoid of the negated inner product of a noise vector with the input vector.
#
# <img src="assets/neg_sampling_loss.png" width=50%>
#
# To give you an intuition for what we're doing here, remember that the sigmoid function returns a probability between 0 and 1. The first term in the loss pushes the probability that our network will predict the correct word $w_O$ towards 1. In the second term, since we are negating the sigmoid input, we're pushing the probabilities of the noise words towards 0.

# %% [markdown]
# **Note:** We use three different forward functions in the model so we get the three different vectors needed to calculate our custom negative sampling loss (they are passed as inputs).

# %%
class SkipGramNeg(nn.Module):
    def __init__(self, n_vocab, n_embed, noise_dist=None):
        super().__init__()
        
        self.n_vocab = n_vocab
        self.n_embed = n_embed
        self.noise_dist = noise_dist
        
        # define embedding layers for input and output words
        self.in_embed = nn.Embedding(n_vocab, n_embed)
        self.out_embed = nn.Embedding(n_vocab, n_embed)
        
        # Initialize both embedding tables with uniform distribution
        # (this may help with convergence)
        self.in_embed.weight.data.uniform_(-1, 1)
        self.out_embed.weight.data.uniform_(-1, 1)
        
    def forward_input(self, input_words):
        input_vectors = self.in_embed(input_words)
        return input_vectors
    
    def forward_output(self, output_words):
        output_vectors = self.out_embed(output_words)
        return output_vectors
    
    def forward_noise(self, batch_size, n_samples):
        """ Generate noise vectors with shape (batch_size, n_samples, n_embed)"""
        if self.noise_dist is None:
            # Sample words uniformly
            noise_dist = torch.ones(self.n_vocab)
        else:
            noise_dist = self.noise_dist
            
        # Sample words from our noise distribution
        noise_words = torch.multinomial(noise_dist,
                                        batch_size * n_samples,
                                        replacement=True)
        
        device = "cuda" if model.out_embed.weight.is_cuda else "cpu"
        noise_words = noise_words.to(device)
        
        noise_vectors = self.out_embed(noise_words).view(batch_size, n_samples, self.n_embed)      
        return noise_vectors

# %%
class NegativeSamplingLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input_vectors, output_vectors, noise_vectors):
        
        batch_size, embed_size = input_vectors.shape
        
        # Input vectors should be a batch of column vectors
        input_vectors = input_vectors.view(batch_size, embed_size, 1)
        
        # Output vectors should be a batch of row vectors
        output_vectors = output_vectors.view(batch_size, 1, embed_size)
        
        # bmm = batch matrix multiplication
        # correct log-sigmoid loss
        out_loss = torch.bmm(output_vectors, input_vectors).sigmoid().log()
        out_loss = out_loss.squeeze()
        
        # incorrect log-sigmoid loss
        noise_loss = torch.bmm(noise_vectors.neg(), input_vectors).sigmoid().log()
        noise_loss = noise_loss.squeeze().sum(1)  # sum the losses over the sample of noise vectors

        # negate and sum correct and noisy log-sigmoid losses
        # return average batch loss
        return -(out_loss + noise_loss).mean()

# %% [markdown]
# ### Training
#
# (Training on GPU recommended, if available.)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Get our noise distribution
# Using word frequencies calculated earlier in the notebook
word_freqs = np.array(sorted(freqs.values(), reverse=True))
unigram_dist = word_freqs/word_freqs.sum()
noise_dist = torch.from_numpy(unigram_dist**(0.75)/np.sum(unigram_dist**(0.75)))

# instantiating the model
embedding_dim = 300
model = SkipGramNeg(len(vocab_to_int), embedding_dim, noise_dist=noise_dist).to(device)

# using the loss that we defined
criterion = NegativeSamplingLoss() 
optimizer = optim.Adam(model.parameters(), lr=0.003)

print_every = 1500
steps = 0
epochs = 5

# train for some number of epochs
for e in range(epochs):
    
    # get our input, target batches
    for input_words, target_words in get_batches(train_words, 512):
        steps += 1
        inputs, targets = torch.LongTensor(input_words), torch.LongTensor(target_words)
        inputs, targets = inputs.to(device), targets.to(device)
        
        # input, outpt, and noise vectors
        input_vectors = model.forward_input(inputs)
        output_vectors = model.forward_output(targets)
        noise_vectors = model.forward_noise(inputs.shape[0], 5)

        # negative sampling loss
        loss = criterion(input_vectors, output_vectors, noise_vectors)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # loss stats
        if steps % print_every == 0:
            print("Epoch: {}/{}".format(e+1, epochs))
            print("Loss: ", loss.item()) # avg batch loss at this point in training
            valid_examples, valid_similarities = cosine_similarity(model.in_embed, device=device)
            _, closest_idxs = valid_similarities.topk(6)

            valid_examples, closest_idxs = valid_examples.to('cpu'), closest_idxs.to('cpu')
            for ii, valid_idx in enumerate(valid_examples):
                closest_words = [int_to_vocab[idx.item()] for idx in closest_idxs[ii]][1:]
                print(int_to_vocab[valid_idx.item()] + " | " + ', '.join(closest_words))
            print("...\n")
# Out:
# Epoch: 1/5
# Loss:  6.709282875061035
# all | beacons, acid, admitted, parks, hooked
# of | the, zero, four, and, one
# was | uniqueness, personal, put, toponyms, saxophonist
# over | qaeda, osmosis, berg, butter, hemispheres
# most | lebanese, alfonso, thousand, ko, arresting
# known | pick, eng, m, t, styled
# into | of, louisiana, technology, these, satellite
# world | suspicion, operating, disease, gregg, verden
# issue | the, apostles, gime, columnists, exmoor
# hit | scope, pericles, mystical, units, auburn
# articles | hermetic, zero, bahrain, locust, lord
# bbc | outdoor, astigmatism, molars, successful, belfast
# engine | mainland, failures, neurosis, stationary, exclude
# marriage | characterization, consummation, try, escape, airtight
# operating | pizza, world, seabed, sailboat, imf
# versions | buckminsterfullerene, viscount, capability, jammed, xenophobic
# ...
#
# Epoch: 1/5
# Loss:  5.273239612579346
# s | in, and, one, to, nine
# that | in, the, to, as, one
# had | february, is, of, irrigated, du
# it | as, to, and, of, in
# there | by, nine, the, to, adam
# zero | one, in, four, of, two
# or | to, a, of, by, and
# have | one, in, it, to, are
# lived | differing, hine, anthropomorphic, leigh, artur
# question | however, alternative, recur, cartoonist, gyula
# know | extents, paper, cymbals, lies, engagement
# account | tsetse, three, manufacturing, me, curries
# engine | two, space, mainland, learns, neurosis
# running | thought, bye, petty, clinch, advanced
# square | munich, history, rica, plantations, derided
# discovered | expulsion, tyrants, nine, monk, cleft
# ...
#
# Epoch: 1/5
# Loss:  4.2739739418029785
# while | it, their, or, the, in
# was | his, in, the, to, he
# about | than, were, in, for, will
# from | of, and, to, with, the
# during | of, which, after, most, one
# this | that, a, to, an, are
# b | zero, one, five, e, s
# time | to, in, the, from, and
# accepted | kicked, most, glottal, which, sufficiently
# bbc | merciless, myr, bernstein, kit, molars
# bill | rebadged, pia, jimmie, trio, democritus
# versions | buckminsterfullerene, predicts, miscellanies, xenophobic, each
# lived | were, spacewalks, housed, hine, navigation
# creation | pirin, keiretsu, conventions, reactos, fellowships
# professional | untaet, maclaurin, frantic, was, guided
# ocean | pour, norden, appointments, progs, mclachlan
# ...
#
# Epoch: 1/5
# Loss:  3.5716145038604736
# th | one, of, the, century, eight
# if | x, be, can, we, any
# nine | six, one, seven, eight, three
# so | be, this, as, more, can
# is | or, an, are, the, with
# more | this, or, often, its, they
# in | the, and, of, after, from
# called | and, is, of, an, to
# behind | player, the, cities, its, scottish
# liberal | germany, against, king, house, held
# universe | t, beersheba, scrooge, anyone, uniformity
# account | subvert, indulgence, forego, manufacturing, esas
# http | links, bedford, org, geminate, formatting
# freedom | laozi, wanted, els, some, continue
# grand | vested, invulnerable, ft, beaten, los
# hold | take, obsession, asserted, term, scores
# ...
#
# Epoch: 1/5
# Loss:  3.0983967781066895
# i | if, his, t, time, is
# as | the, a, in, and, of
# most | a, the, from, to, in
# no | if, this, that, or, it
# have | not, a, that, they, this
# used | a, is, use, like, it
# history | by, in, century, links, new
# will | that, would, but, should, you
# pressure | large, missiles, water, dishes, usually
# additional | done, hausdorff, continue, such, systema
# powers | if, governments, owed, u, paragliding
# engine | fuel, speed, powered, stroke, jet
# award | d, fiction, actor, four, jack
# numerous | from, his, history, to, did
# pre | asia, which, catholic, gunfire, mussels
# grand | george, nine, country, paul, vested
# ...
#
# Epoch: 1/5
# Loss:  3.1698575019836426
# over | country, of, year, or, years
# no | that, to, subject, the, them
# time | to, with, on, not, was
# first | nine, one, four, three, six
# five | two, one, four, six, zero
# on | a, and, the, of, with
# at | and, of, the, a, s
# is | g, and, or, used, other
# applications | computer, information, software, systems, system
# defense | government, forces, murder, police, rights
# paris | charles, de, one, seven, william
# magazine | author, books, zero, jerry, album
# woman | born, his, her, death, wife
# something | get, him, that, what, this
# channel | radio, video, network, service, television
# consists | are, also, the, typically, or
# ...
#
# Epoch: 2/5
# Loss:  2.545917272567749
# between | to, is, the, this, in
# after | war, had, in, during, declared
# which | are, the, to, and, is
# such | are, for, many, is, often
# has | in, and, high, through, the
# years | five, male, female, population, total
# four | five, one, seven, two, six
# up | could, first, they, out, made
# brother | daughter, wife, emperor, iii, his
# issue | leadership, political, issues, committee, argue
# governor | minister, elected, house, president, parliamentary
# mean | y, function, n, frac, is
# arts | art, school, university, institute, museum
# lived | father, succeeded, had, rome, capital
# recorded | songs, lee, record, rock, album
# pressure | temperature, prevent, pressures, result, conditions
# ...
#
# Epoch: 2/5
# Loss:  2.9406158924102783
# his | he, him, himself, who, son
# for | and, the, in, a, on
# into | the, to, and, for, this
# used | uses, using, process, use, are
# new | york, and, s, on, one
# i | t, p, n, himself, then
# at | for, the, one, in, two
# and | of, the, by, in, is
# accepted | question, should, generally, strictly, considered
# something | you, it, your, know, my
# notes | is, musical, tone, article, e
# operating | software, computers, microsoft, ibm, hardware
# discovered | sky, observed, planet, about, identified
# defense | forces, combat, armed, police, weapons
# event | internationalist, starts, seeking, spirituals, ribbons
# liberal | party, liberals, parties, conservative, conservatives
# ...
#
# Epoch: 2/5
# Loss:  2.679725170135498
# he | his, him, her, asked, she
# i | n, k, let, v, r
# which | a, is, in, of, and
# four | six, one, three, two, five
# not | that, they, often, do, does
# s | robert, of, his, john, mother
# his | he, was, son, author, father
# state | law, federal, constant, proportional, energy
# heavy | metal, vehicles, air, guns, drilling
# behind | team, players, player, down, forward
# accepted | practical, science, concerning, those, do
# report | organizations, department, fraud, abuse, committee
# road | near, valley, town, feet, miles
# taking | an, following, to, right, assume
# older | age, median, families, rate, poverty
# hit | songs, singles, album, hits, tour
# ...
#
# Epoch: 2/5
# Loss:  2.6676130294799805
# more | than, such, less, either, often
# that | cannot, not, do, is, be
# there | are, that, this, for, meaning
# on | and, for, to, in, the
# between | the, and, its, of, into
# in | by, the, had, of, and
# if | we, can, must, be, follows
# were | their, had, war, and, out
# something | you, good, thing, how, many
# taking | having, were, off, their, but
# numerous | languages, most, including, established, ethnic
# nobel | prize, laureate, physicist, physiology, chemist
# applications | data, processing, functional, analysis, using
# ice | snow, dry, rock, glaciers, rocks
# defense | civilian, military, armed, targets, united
# versions | version, microsoft, windows, user, drive
# ...
#
# Epoch: 2/5
# Loss:  2.63667368888855
# will | do, does, be, if, would
# are | is, and, or, from, the
# over | four, one, in, was, to
# where | left, the, in, is, moved
# a | is, or, also, the, in
# only | to, the, when, a, will
# that | not, be, as, they, god
# system | systems, lines, common, internal, term
# pope | bishops, archbishop, emperor, holy, papacy
# centre | town, buildings, located, area, west
# recorded | songs, album, band, song, concert
# professional | football, college, league, sports, fame
# lived | village, wife, born, began, son
# mathematics | mathematical, physics, mathematicians, theory, philosophy
# consists | consist, is, above, also, difference
# primarily | from, mainly, small, and, heavily
# ...
#
# Epoch: 2/5
# Loss:  2.7004661560058594
# however | to, not, due, the, an
# all | their, it, that, not, to
# called | or, is, used, and, a
# a | the, of, is, and, which
# so | that, be, it, or, are
# many | are, some, non, other, to
# his | he, her, him, himself, she
# not | that, does, we, simply, to
# brother | son, younger, daughter, father, grandfather
# prince | duke, emperor, ii, iv, queen
# smith | craig, gordon, singer, paul, richard
# professional | team, amateur, organizations, league, australian
# issue | union, countries, nations, committee, truman
# egypt | syria, egyptian, turks, conquered, jerusalem
# applications | software, systems, operating, computer, hardware
# test | tests, nuclear, tested, testing, however
# ...
#
# Epoch: 3/5
# Loss:  2.3458876609802246
# has | and, its, the, many, significant
# than | less, is, its, because, and
# were | was, by, and, the, have
# two | zero, four, six, five, one
# most | the, and, is, in, are
# d | laureate, b, writer, nobel, born
# war | troops, civil, battle, invasion, forces
# by | the, and, of, were, was
# units | unit, infantry, measurement, ammunition, forces
# placed | attached, onto, painted, not, inside
# hold | held, of, the, their, without
# accepted | proponents, law, explain, recognize, approval
# quite | easily, still, them, found, sometimes
# scale | scales, tuning, chords, instruments, logarithmic
# bbc | april, day, news, february, listing
# engineering | technology, engineers, design, automotive, manufacturing
# ...
#
# Epoch: 3/5
# Loss:  2.5161478519439697
# when | a, to, it, up, either
# a | the, is, in, as, or
# that | it, if, not, a, are
# it | that, to, which, a, if
# eight | five, one, four, seven, nine
# in | the, and, a, first, one
# after | shortly, he, was, later, had
# the | in, and, a, of, from
# egypt | syria, egyptian, bc, muslim, conquered
# alternative | term, hop, related, complementary, been
# lived | sons, family, married, son, slaves
# grand | july, six, december, danish, duke
# something | things, knowing, you, when, me
# brother | son, daughter, princess, grandmother, he
# existence | our, god, eternal, religion, argument
# older | families, household, size, females, population
# ...
#
# Epoch: 3/5
# Loss:  2.4189341068267822
# state | government, energy, charge, delta, constituent
# as | of, in, are, to, other
# of | in, the, as, and, which
# while | with, the, that, are, of
# and | in, the, of, also, from
# not | should, that, to, but, be
# many | different, most, of, and, have
# war | civil, troops, soviet, independence, empire
# orthodox | church, churches, catholic, oriental, rite
# hit | hits, album, singles, songs, song
# existence | concepts, sense, eternal, philosophers, notion
# freedom | liberty, freedoms, moral, public, communism
# http | www, html, htm, links, edu
# channel | channels, cable, station, stations, radio
# older | families, males, household, age, family
# square | coordinates, adjacent, covers, bounded, cubic
# ...
#
# Epoch: 3/5
# Loss:  2.6642534732818604
# are | is, distinct, or, sometimes, some
# nine | seven, one, two, eight, four
# some | or, other, have, are, also
# zero | five, four, two, one, seven
# so | be, there, always, will, if
# history | th, modern, external, links, century
# b | d, c, j, laureate, politician
# five | zero, two, four, seven, six
# primarily | many, these, creating, such, use
# bible | testament, biblical, tanakh, judaism, christ
# file | files, user, software, html, server
# marriage | married, daughter, wife, marry, husband
# derived | forms, is, derive, hence, adjective
# award | awards, best, hugo, oscar, emmy
# hit | hits, album, singles, debut, roll
# something | anything, get, you, wants, fun
# ...
#
# Epoch: 3/5
# Loss:  2.4229612350463867
# to | of, the, but, they, would
# from | and, in, the, a, by
# two | zero, five, six, four, seven
# four | seven, three, five, one, six
# s | was, of, and, nine, by
# if | we, let, your, you, i
# five | seven, four, two, three, zero
# he | his, had, him, fellow, to
# file | files, software, windows, interface, unix
# taking | who, led, after, having, forced
# magazine | edited, magazines, science, awards, website
# additional | below, added, these, extra, allows
# liberal | democrat, conservative, political, party, conservatives
# cost | costs, price, costly, reduce, infrastructure
# gold | silver, precious, copper, nickel, mineral
# something | anything, wants, you, how, what
# ...
#
# Epoch: 3/5
# Loss:  2.5273971557617188
# the | a, with, and, is, of
# or | are, be, often, usually, is
# is | the, a, it, has, of
# state | democratic, national, states, counties, representatives
# these | such, are, other, different, is
# more | are, and, than, it, as
# however | to, this, a, is, not
# world | war, championships, international, us, first
# pressure | temperature, pump, resulting, exhaust, increases
# institute | university, research, faculty, college, education
# assembly | legislative, seats, elected, elections, chairman
# versions | windows, version, mac, interface, microsoft
# quite | many, which, so, variety, unlike
# taking | of, turn, important, prevent, takes
# notes | tone, poetry, pages, works, writing
# except | are, generally, vowels, into, only
# ...
#
# Epoch: 4/5
# Loss:  2.3765664100646973
# with | in, the, to, of, was
# s | the, of, by, nine, on
# zero | two, five, six, one, eight
# are | is, other, typically, as, use
# no | to, considered, not, feel, but
# been | the, were, of, have, was
# would | that, never, than, a, this
# not | to, but, that, it, be
# applications | proprietary, windows, systems, operating, devices
# experience | psychological, thinking, pain, perception, experiences
# engineering | design, engineers, technology, technical, management
# smith | musician, canadian, songwriter, john, singer
# numerous | into, and, north, to, in
# applied | of, used, styles, equivalent, is
# discovered | discovery, crater, copper, references, specimen
# arts | art, schools, martial, academy, school
# ...
#
# Epoch: 4/5
# Loss:  2.2272121906280518
# would | never, will, they, this, that
# called | are, is, contain, a, that
# most | as, more, in, both, such
# that | a, not, be, it, they
# while | be, than, without, a, have
# and | of, in, the, a, or
# up | to, the, a, out, them
# i | t, ve, you, ll, let
# arts | art, martial, academy, theatre, schools
# frac | sqrt, cdot, equation, phi, omega
# existence | our, whether, sense, eternal, deny
# question | whether, questions, validity, conclusion, argument
# universe | cosmic, bang, matter, physics, universes
# event | encounter, exactly, occurrence, occurred, since
# older | families, years, poverty, household, size
# additional | composite, equipment, welded, replacing, combination
# ...
#
# Epoch: 4/5
# Loss:  2.40899920463562
# called | is, also, an, other, are
# that | not, to, are, the, only
# was | s, had, until, his, son
# world | links, new, of, in, project
# or | be, is, the, a, of
# history | th, century, origins, references, historical
# most | as, other, in, the, many
# known | in, from, as, of, two
# orthodox | church, orthodoxy, eastern, rite, christians
# something | do, should, you, cannot, how
# award | awards, oscar, grammy, winners, awarded
# heavy | heavier, trucks, helicopters, metal, vehicles
# know | you, we, my, t, not
# paris | france, des, fran, du, le
# resources | resource, information, management, development, aims
# accepted | generally, date, disputes, certain, recognized
# ...
#
# Epoch: 4/5
# Loss:  2.4044246673583984
# its | on, a, the, has, in
# has | a, been, is, its, also
# may | are, be, to, is, of
# about | zero, the, of, estimates, in
# while | an, to, some, and, long
# five | two, zero, seven, four, one
# four | one, seven, zero, two, three
# three | one, seven, two, four, zero
# bible | biblical, testament, judaism, tanakh, prophets
# award | oscar, awards, emmy, awarded, hugo
# pressure | temperature, heat, temperatures, cold, liquid
# instance | example, different, a, be, there
# proposed | new, its, conclusions, argued, known
# egypt | syria, egyptian, sinai, arab, ancient
# quite | are, very, less, either, simple
# defense | defence, military, war, service, strategic
# ...
#
# Epoch: 4/5
# Loss:  2.5712852478027344
# and | in, the, of, as, also
# was | s, after, in, the, with
# war | world, forces, troops, allied, battle
# states | united, state, u, president, former
# these | such, different, to, be, have
# i | me, my, t, want, we
# many | well, most, and, other, in
# four | three, six, zero, seven, five
# universe | universes, cosmic, galaxy, alien, existence
# paris | du, des, france, la, le
# alternative | frequently, particular, specifically, written, argued
# numerous | several, prominent, some, considered, written
# notes | tone, chord, c, allegro, works
# bbc | external, news, listing, links, day
# nobel | prize, laureate, chemist, physicist, recipient
# brother | son, died, eldest, daughter, children
# ...
#
# Epoch: 4/5
# Loss:  2.2336103916168213
# as | the, a, and, for, other
# zero | two, four, three, one, six
# its | has, as, an, it, which
# over | at, was, years, next, a
# see | external, links, also, history, references
# such | are, other, use, as, and
# during | was, after, the, occurred, period
# there | are, that, between, from, many
# creation | attempts, implementation, its, become, intention
# pope | papal, roman, emperor, archbishop, pius
# derived | derive, called, used, maxwell, employed
# brother | son, father, daughter, wife, younger
# operations | operation, armed, operational, attack, personnel
# joseph | historian, thomas, alexander, physician, james
# applied | using, methods, field, theory, describes
# engine | engines, powered, combustion, fuel, turbine
# ...
#
# Epoch: 5/5
# Loss:  2.3112831115722656
# years | two, five, six, female, four
# these | are, other, such, different, called
# this | of, to, the, only, be
# seven | five, six, four, one, two
# people | many, those, speak, citizens, there
# called | these, also, is, are, a
# with | of, the, for, this, in
# his | he, father, him, wrote, son
# http | www, html, org, htm, com
# engine | engines, fuel, powered, combustion, turbine
# universe | universes, existence, cosmic, infinite, real
# marriage | wife, married, marry, marriages, woman
# applied | modern, method, referred, types, see
# cost | costs, expensive, price, low, amount
# proposed | theory, gravitational, fundamental, debate, hypothesis
# animals | plants, humans, insects, mammals, animal
# ...
#
# Epoch: 5/5
# Loss:  2.1830976009368896
# use | used, commonly, common, often, usually
# while | when, not, the, to, often
# seven | four, five, six, nine, eight
# his | he, him, s, career, himself
# nine | one, seven, six, zero, eight
# d | b, g, ois, nine, r
# no | there, that, it, not, a
# war | forces, army, france, german, soldiers
# professional | association, amateur, sports, training, football
# scale | scales, timescale, processes, tuning, materials
# file | files, software, default, data, windows
# know | you, your, do, me, don
# woman | children, female, child, birth, sex
# mainly | areas, mostly, more, region, non
# smith | joseph, peter, gordon, john, jay
# mean | is, frac, arithmetic, equivalent, n
# ...
#
# Epoch: 5/5
# Loss:  2.4811718463897705
# where | is, to, we, near, then
# state | states, energy, college, delta, united
# into | were, this, a, of, to
# th | century, nd, rd, seven, five
# s | one, was, of, to, his
# people | americans, peoples, central, speak, native
# no | it, that, in, only, but
# be | this, is, that, an, a
# except | any, own, must, directly, if
# square | adjacent, edge, coordinates, approximately, height
# something | anything, things, you, so, my
# mathematics | mathematical, algebra, mathematicians, calculus, solving
# dr | singer, robert, he, professor, guest
# quite | interesting, most, means, are, found
# http | www, html, htm, org, com
# egypt | egyptian, syria, arab, sinai, cairo
# ...
#
# Epoch: 5/5
# Loss:  2.2552473545074463
# or | is, are, which, have, other
# been | have, early, were, has, some
# more | are, most, of, or, have
# will | if, possible, be, give, so
# time | after, before, only, when, because
# also | and, see, is, of, for
# be | that, is, so, to, are
# most | in, some, of, more, many
# hit | hits, singles, album, debut, charts
# additional | required, produce, contain, usually, or
# numerous | been, among, many, were, though
# institute | university, technology, conferences, school, faculty
# mean | means, frac, suppose, statement, radii
# channel | channels, broadcasts, cable, television, signals
# question | not, cannot, statement, whether, essence
# smith | james, gordon, joseph, peter, craig
# ...
#
# Epoch: 5/5
# Loss:  2.2246317863464355
# in | the, and, to, from, of
# for | a, an, s, by, is
# many | well, some, and, among, often
# called | a, the, which, is, used
# often | many, to, some, such, non
# other | are, some, these, also, to
# such | is, as, both, including, those
# first | one, on, was, after, in
# quite | even, it, long, because, i
# except | proper, only, them, unlike, while
# animals | species, humans, birds, insects, teeth
# grand | prix, lodge, duchy, duke, road
# award | awards, hugo, best, winners, awarded
# ocean | pacific, atlantic, islands, sea, km
# units | unit, infantry, si, cavalry, battalion
# http | www, html, htm, com, edu
# ...
#
# Epoch: 5/5
# Loss:  2.1556482315063477
# from | also, the, of, a, is
# this | the, a, to, it, of
# be | that, only, or, it, because
# it | to, the, its, a, this
# four | five, three, one, six, two
# but | they, that, be, were, and
# their | would, to, they, be, have
# may | is, also, from, occur, occurs
# pressure | fluid, temperature, pump, hydraulic, pressures
# issue | disagreements, outrage, tensions, complaints, political
# shown | if, is, are, pair, called
# paris | france, des, de, du, le
# instance | case, above, often, simply, using
# resources | resource, information, article, management, org
# question | answer, whether, sentences, false, questions
# marriage | marriages, divorce, married, marry, marital
# ...

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
# getting embeddings from the embedding layer of our model, by name
embeddings = model.in_embed.weight.to('cpu').data.numpy()

# %%
viz_words = 300
tsne = TSNE()
embed_tsne = tsne.fit_transform(embeddings[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# ---
